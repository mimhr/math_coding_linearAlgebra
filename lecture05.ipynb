# %% [markdown]
# jyupter上のlatexで数式内に日本語を書くと、github上ではうまく動作しません。
#
# [Jupyter nbviewer](http://nbviewer.jupyter.org/)のページで当ページのURLを貼り付けて、表示させてください。

# %% [markdown]
# ## 6.4 一次独立(一次関係という言葉は特にいらないような気がする)
#
# ### 一般形
# $\textbf{a}_{i} \in V (i=1,..,n)$が一次独立であるとは、
# $$
# c_{1}\textbf{a}_{1}+c_{2}\textbf{a}_{2}+...+c_{n}\textbf{a}_{n}=0
# $$
# が$c_{1}=c_{2}=...=c_{n}=0$のときにしか成り立たない。
#
# #### 一次従属(論理の言葉でいえば「一次独立」の対偶)
# $\textbf{a}_{i} \in V (i=1,..,n)$が一次従属であるとは、
#
# $$
# c_{1}\textbf{a}_{1}+c_{2}\textbf{a}_{2}+...+c_{n}\textbf{a}_{n}=0
# $$
#
# となるのは、$c_{1},c_{2},...,c_{n}$のどれか一つ、もしくは一つ以上が$0$でない。(=少なくとも一つが0でない)
#
# 要するに、$\textbf{a}_{i} \in V (i=1,..,n)$を組合せて、ゼロベクトルにすることができる(原点を指すことができる)ということ。
#
#
#
# ### 2次元で考えます。
#
# $a_{i} \in V (i=1,2)$について
# $$
# c_{1}\textbf{a}_{1}+c_{2}\textbf{a}_{2}=0
# $$
# が$c_{1}=c_{2}=0$のときにしか成り立たない。
#
# + $\textbf{a}_{1}$は$\textbf{a}_{2}$を使っても言い換えができないということ。つまり、
#
# $$
# \textbf{a}_{1}=\alpha\textbf{a}_{2}
# $$
#
# というような$\alpha \in \mathbb{R}$は存在しえない。
#
# ところで、$\textbf{a}\parallel\textbf{b}$であるとき、スカラー積を用いることで、
#
# $$
# \textbf{a}=\alpha\textbf{b}
# $$
#
# と表現できる。1次独立のとき$\textbf{a}_{1}\neq\alpha\textbf{a}_{2}$であるから、$\textbf{a}\not\parallel\textbf{b}$となる。
# (p.128,"一次独立と1次従属の幾何学的意味(3)")
#
# + 不要なベクトルを排除して、必要最低限のベクトルで空間を表現したい時に一次独立を定義します。(p.126,コメント)
#
# + 必ずしも$a_{i} \in V (i=1,2)$のそれぞれが直交していなくていい(p.262, 正規直交基底)
#
# ### 例:色の三原色(極端な例、ぱっと思い浮かんだだけなので、間違っているかも)
#
# 三原色(青、赤、黄)は、この三色を基底$\textbf{color}_{i}\in \mathbb{R}^{3}$として、$0\le c_i\le1$、$c_i\in\mathbb{R}$を用いて、特徴空間(ベクトル空間)をなし、$\textbf{color}_{i}$のそれぞれは一次独立の関係にある。すなわち、
#
# $$
# c_{blue}\textbf{Color}_{blue}+c_{red}\textbf{Color}_{red}+c_{yellow}\textbf{Color}_{yellow}=0,\quad ただし等号はc_i=0のときのみ
# $$
#
# + 要するに「青は赤や黄では表現できない」(ある原色は他の原色を使って表現できない)ということ。
# + $c_i\neq 0$のとき、何らかの色となる(ゼロベクトルならず、どこか原点以外のところを指す)。すなわち、
#
# $$
# c_{blue}\textbf{Color}_{blue}+c_{red}\textbf{Color}_{red}+c_{yellow}\textbf{Color}_{yellow}\neq 0,\quad ただしc_i\neq 0
# $$
#
# ## 定理を総ざらい(やっている時間がないので。私観によればこういうのは定理ではない)
#
# <img src="./img/theorem644.jpg" style="width: 600px">
#
# #### これは自明
#
# <img src="./img/theorem645.jpg" style="width: 600px">
#
# #### これは自明
#
# <img src="./img/theorem646.jpg" style="width: 600px">
#
# #### これは自明
#
# ### 1次結合の行列表記と線形写像(p.123)
# ベクトル空間$V$の$m$個のベクトルの組$\textbf{u}_{1}$、...、$\textbf{u}_{m}$と$m\times n$行列$A=(a_{ij})$に対して、
# $$
# \begin{eqnarray*}
# (\textbf{u}_{1},...,\textbf{u}_{m})A&=&(\textbf{u}_{1},...,\textbf{u}_{m})\left(\begin{array}{ccc}
# a_{11} & ... & a_{1n} \\
# a_{21} & ... & a_{2n} \\
# ... & ... & ... \\
# a_{m1} & ... & a_{mn} \\
# \end{array}
# \right)
# &=&\left(\sum_{i=1}^{m}a_{i1}\textbf{u}_{i},\sum_{i=1}^{m}a_{i2}\textbf{u}_{i},...,\sum_{i=1}^{m}a_{in}\textbf{u}_{i}\right)
# \end{eqnarray*}
# $$
#
# <img src="./img/theorem647.jpg" style="width: 600px">
#
# #### もう少しやさしく書くと
#
# 1次独立の定義は
#
# $$
# c_{1}\textbf{a}_{1}+c_{2}\textbf{a}_{2}+...+c_{m}\textbf{a}_{m}=0
# $$
# が$c_{1}=c_{2}=...=c_{m}=0$のときにしか成り立たない。
#
# でした。
#
# これを行列の積で書きなおすと
# $$
# (\textbf{a}_{1},\textbf{a}_{2},...,\textbf{a}_{m})\left(\begin{array}{c}
# c_{1} \\
# c_{2} \\
# ... \\
# c_{m} \\
# \end{array}
# \right)=(\textbf{a}_{1},\textbf{a}_{2},...,\textbf{a}_{m})\textbf{c}=\textbf{0}
# $$
#
# $\textbf{a}_{i} \in V (i=1,..,n)$が1次独立のとき、いかなる$\textbf{c}$について$\textbf{c}=\textbf{0}$であるから、あえてそれらを行列で書くと、
#
# $$
# (\textbf{a}_{1},\textbf{a}_{2},...,\textbf{a}_{m})(\textbf{c}_{1},\textbf{c}_{2},...,\textbf{c}_{n})
# =(\textbf{a}_{1},\textbf{a}_{2},...,\textbf{a}_{m})A=(\textbf{0},...,\textbf{0})
# $$
#
# $\textbf{c}_{i}=\textbf{0}$であったので、
#
# $$
# A=(\textbf{c}_{1},\textbf{c}_{2},...,\textbf{c}_{n})=(\textbf{0},...,\textbf{0})=0
# $$
#
# <img src="./img/theorem648.jpg" style="width: 600px">

# %% [markdown]
# ## 6.5 連立斉次1次方程式(p.134)
#
# ### せい【斉〔齊〕】の意味
#
# + 凸凹がなく等しくそろっている。そろえる。ととのえる。
# + 中国、春秋時代の国名。
#
# 斉次1次方程式とは、「非零項がすべて同じ次数である」ような方程式。そのような斉次な1次方程式の連立を考える。
# $$
# \begin{eqnarray}
# \left\{
# \begin{array}{l}
# a_{11}x_{1}+...a_{1n}x_{n}=0 \\
# a_{21}x_{1}+...a_{2n}x_{n}=0 \\
# ..... \\
# a_{n1}x_{1}+...a_{nn}x_{n}=0 \\
# \end{array}
# \right.
# \end{eqnarray}
# $$
#
# は行列とベクトルを用いることで
#
# $$
# A\textbf{x}=0,\quad
# A=\left(\begin{array}{ccc}
# a_{11} & ... & a_{1n} \\
# a_{21} & ... & a_{2n} \\
# ... & ... & ... \\
# a_{n1} & ... & a_{nn} \\
# \end{array}
# \right),\quad \textbf{x}=\left(\begin{array}{ccc}
# x_1 \\
# x_2 \\
# ... \\
# x_n \\
# \end{array}
# \right)
# $$
#
# + 自明な解$\textbf{x}=0$
# + 解空間。すなわち$A\textbf{x}=0$をみたす$\textbf{x}$が張る空間。これはKernelですね。
# + 自明な解以外の解を持つための必要十分条件は$|A|=0$(定理6.5.1)
#
# 教科書は丁寧にやっているけれど、僕のテキトー証明は以下。(ちゃんとした証明は教科書を参考ください)
#
# $|A|\neq 0$のとき、$A$は逆行列を持ち、
# $$
# A\textbf{x}=0 \\
# A^{-1}A\textbf{x}=0
# $$
# となり、
# $$
# \textbf{x}=0
# $$
# と自明な解となる。
# このようにならないためには、「$A$は逆行列をもたない、すなわち$|A|=0$であること」が条件となる。
#
# イメージは、
# $$
# \textbf{0}\textbf{x}=0
# $$
# ように、総体として0になる行列である、という感じ。
#
# 演算として、$A\textbf{x}=0$を$\textbf{x}=0$にもっていけないのです。

# %% [markdown]
# ## 6.6 行列式と1次独立性の関係
#
# <img src="./img/theorem661.jpg" style="width: 600px">
#
# ### (1)=(2)
#
# $$
# A=\left(\begin{array}{c}
# \textbf{a}_{1} \\
# ... \\
# \textbf{a}_{n} \\
# \end{array}
# \right)=(\textbf{a}_{1}',...,\textbf{a}_{n}')
# $$
#
# のとき、
#
# $$
# A\textbf{x}=(\textbf{a}_{1}',...,\textbf{a}_{n}')\left(\begin{array}{c}
# x_{1} \\
# ... \\
# x_{n} \\
# \end{array}
# \right)=\textbf{0}
# $$
# に対しては、
#
# + $\det A=0$のとき、$\textbf{x}$は自明以外の解を持つ
# + $\det A\neq0$のとき、$\textbf{x}=\textbf{0}$なる自明の解しか持ち得ない
#
# ところで、この状況での1次独立は「$\sum_{i=1}^{n}\textbf{a}_{i}'x_{i}=0$は$x_{i}=0$のときしか成立しない」といえるので、「$\textbf{x}=\textbf{0}$なる自明の解しか持ち得ない」ということになる。
#
# すなわち、$\det A\neq0$のとき$(\textbf{a}_{1}',...,\textbf{a}_{n}')$は1次独立。
#
# ### (1)=(3)
#
# 転置すればOK

# %% [markdown]
# ## 6.7 ベクトル空間の基底
#
# 教科書で。
#
# <img src="./img/theorem511.jpg" style="width: 600px">

# %% [markdown]
# ## 6.8 ベクトル空間の次元
#
# 教科書で。
#
# ### 定義6.8.1
#
# ベクトル空間$V$に対して、定理6.8.2によって定まる基底のベクトルの個数をベクトル空間の次元(Dimension)といい、$\dim V$と表す。
#
# 大切なのは次の2つ。
#
# <img src="./img/theorem687.jpg" style="width: 600px">
#
# <img src="./img/theorem688.jpg" style="width: 600px">

# %% [markdown]
# ## 6.9 基底の間の関係
#
# <img src="./img/theorem691.jpg" style="width: 600px">
#
# これをちゃんとに書くと、
#
# <img src="./img/p152.jpg" style="width: 600px">
#
# これは6.10 線形写像の行列表現(p.152)。ということで、そこまで飛びます。

# %% [markdown]
# ## 6.10 線形写像の行列表現
#
# ### p.153
#
# <img src="./img/p153-1.jpg" style="width: 600px">
# <img src="./img/p153-2.jpg" style="width: 600px">
#
# p.232をちらみしてみてください。
#
# ### 物理数学的には(この場合は直交変換(計量同型 p.269)に限ってのハナシなんですけど)
#
# $A$なる行列で、
# $$
# A\textbf{x}=\textbf{x}'
# $$
# という変換を考える。
#
#
# 内積は変換前後で保たれるべきあるから(計量同型,p.269)、
# $$
# (\textbf{x}|\textbf{x})=(\textbf{x}'|\textbf{x}')
# $$
#
# ところで、
# $$
# |A\textbf{x})^{*}=(\textbf{x}|A^{*}
# $$
#
# だから、上式の2式目はつぎのようにできる。
#
# $$
# (\textbf{x}'|\textbf{x}')=(A\textbf{x}|A\textbf{x})=(\textbf{x}|A^{*}A|\textbf{x})
# $$
#
# すなわち、
# $$
# A^{*}A=E_{n}
# $$
# となり、これは$A$がUnitaryであることを示している。以後、$A$をUnitary行列として、$U$と記述する。
#
# $\textbf{x}$が張る空間でのある行列$B$、$\textbf{x}'$が張る空間でのある行列$B'$を考える。
#
# $$
# (\textbf{x}'|B'|\textbf{x}')=(U\textbf{x}|B'|U\textbf{x})=(\textbf{x}|U^{*}B'U|\textbf{x})
# $$
#
# またこれは下記と同義であり、
# $$
# (\textbf{x}|B|\textbf{x})
# $$
#
# つまり、
# $$
# B=U^{*}B'U=U^{-1}B'U
# $$

# %% [markdown]
# ## 6.11 ベクトル空間の同型
#
# 教科書で。

# %% [markdown]
# ## 6.12 商ベクトル空間
